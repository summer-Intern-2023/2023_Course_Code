# %%
#Extracting Date
import re
name = input("Enter the file:")
fh = open('src/' + name)
cont = fh.read()
nums = re.findall('[0-9]+', cont)
total = 0
for num in nums:
    total = total + int(num)

    print(total)
# Out:
# ['7372', '1229', '7408', '6892', '6683', '7977', '540', '1099', '7810', '8968', '8079', '8338', '32', '6868', '6403', '5110', '93', '2527', '7329', '4662', '9633', '1424', '620', '4444', '7281', '1859', '1873', '9653', '7774', '4370', '762', '1155', '3617', '3694', '3087', '3656', '4', '8001', '9607', '201', '200', '2132', '3697', '5066', '780', '3121', '3183', '1137', '8835', '3085', '6785', '6488', '3677', '6899', '3456', '5333', '558', '6337', '1438', '7228', '3286', '4', '3', '42']
# 7372
# 8601
# 16009
# 22901
# 29584
# 37561
# 38101
# 39200
# 47010
# 55978
# 64057
# 72395
# 72427
# 79295
# 85698
# 90808
# 90901
# 93428
# 100757
# 105419
# 115052
# 116476
# 117096
# 121540
# 128821
# 130680
# 132553
# 142206
# 149980
# 154350
# 155112
# 156267
# 159884
# 163578
# 166665
# 170321
# 170325
# 178326
# 187933
# 188134
# 188334
# 190466
# 194163
# 199229
# 200009
# 203130
# 206313
# 207450
# 216285
# 219370
# 226155
# 232643
# 236320
# 243219
# 246675
# 252008
# 252566
# 258903
# ...
