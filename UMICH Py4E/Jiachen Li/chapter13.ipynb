# %%
text = '''
<commentinfo>
  <note>This file contains the actual data for your assignment - good luck!</note>

  <comments>
    <comment>
       <name>Saba</name>
       <count>100</count>
    </comment>
    <comment>
       <name>Tessa</name>
       <count>100</count>
    </comment>
    <comment>
       <name>Idahosa</name>
       <count>96</count>
    </comment>
    <comment>
       <name>Sacha</name>
       <count>94</count>
    </comment>
    <comment>
       <name>TJ</name>
       <count>92</count>
    </comment>
    <comment>
       <name>Zach</name>
       <count>92</count>
    </comment>
    <comment>
       <name>Ramsey</name>
       <count>90</count>
    </comment>
    <comment>
       <name>Zohair</name>
       <count>90</count>
    </comment>
    <comment>
       <name>Fyfe</name>
       <count>90</count>
    </comment>
    <comment>
       <name>Devin</name>
       <count>84</count>
    </comment>
    <comment>
       <name>Launi</name>
       <count>81</count>
    </comment>
    <comment>
       <name>Ayse</name>
       <count>80</count>
    </comment>
    <comment>
       <name>Innes</name>
       <count>79</count>
    </comment>
    <comment>
       <name>Bronagh</name>
       <count>78</count>
    </comment>
    <comment>
       <name>Kalen</name>
       <count>77</count>
    </comment>
    <comment>
       <name>Betty</name>
       <count>70</count>
    </comment>
    <comment>
       <name>Alistar</name>
       <count>69</count>
    </comment>
    <comment>
       <name>Riya</name>
       <count>68</count>
    </comment>
    <comment>
       <name>Taqwah</name>
       <count>66</count>
    </comment>
    <comment>
       <name>Noah</name>
       <count>65</count>
    </comment>
    <comment>
       <name>Kayda</name>
       <count>65</count>
    </comment>
    <comment>
       <name>Freia</name>
       <count>62</count>
    </comment>
    <comment>
       <name>Kaitlynn</name>
       <count>61</count>
    </comment>
    <comment>
       <name>Jago</name>
       <count>45</count>
    </comment>
    <comment>
       <name>Eihli</name>
       <count>38</count>
    </comment>
    <comment>
       <name>Amina</name>
       <count>36</count>
    </comment>
    <comment>
       <name>Malikah</name>
       <count>34</count>
    </comment>
    <comment>
       <name>Dilan</name>
       <count>32</count>
    </comment>
    <comment>
       <name>Alani</name>
       <count>31</count>
    </comment>
    <comment>
       <name>Clayton</name>
       <count>30</count>
    </comment>
    <comment>
       <name>Mackenzie</name>
       <count>30</count>
    </comment>
    <comment>
       <name>Evelina</name>
       <count>28</count>
    </comment>
    <comment>
       <name>Aliekber</name>
       <count>26</count>
    </comment>
    <comment>
       <name>Jebadiah</name>
       <count>25</count>
    </comment>
    <comment>
       <name>Eiley</name>
       <count>23</count>
    </comment>
    <comment>
       <name>Clove</name>
       <count>22</count>
    </comment>
    <comment>
       <name>Elizabeth</name>
       <count>21</count>
    </comment>
    <comment>
       <name>Roxanna</name>
       <count>15</count>
    </comment>
    <comment>
       <name>Oakley</name>
       <count>15</count>
    </comment>
    <comment>
       <name>Ailie</name>
       <count>14</count>
    </comment>
    <comment>
       <name>Bushra</name>
       <count>13</count>
    </comment>
    <comment>
       <name>Olurotimi</name>
       <count>12</count>
    </comment>
    <comment>
       <name>Enrico</name>
       <count>11</count>
    </comment>
    <comment>
       <name>Sheigh</name>
       <count>10</count>
    </comment>
    <comment>
       <name>Reean</name>
       <count>8</count>
    </comment>
    <comment>
       <name>Emowyn</name>
       <count>7</count>
    </comment>
    <comment>
       <name>Alleisha</name>
       <count>7</count>
    </comment>
    <comment>
       <name>Tai</name>
       <count>7</count>
    </comment>
    <comment>
       <name>Jura</name>
       <count>4</count>
    </comment>
    <comment>
       <name>Fedora</name>
       <count>2</count>
    </comment>
  </comments>
</commentinfo>


'''

# %%
import xml.etree.ElementTree as ET
root = ET.fromstring(text)
lst = root.findall('comments/comment')

count, sum = 0, 0
for item in lst:
    count += 1
    #print(item.find('name').text)
    sum += int(item.find('count').text)
print(sum)
# Out:
# 2395

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl
import re

api_key = False
# If you have a Google Places API key, enter it here
api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/xml?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/xml?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE


while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms) 
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    print(uh)

    data = uh.read().decode()
    print("data: ", data)
    data = re.sub(u"[\x00-\x08\x0b-\x0c\x0e-\x1f]+", u"", data)
    print('Retrieved', len(data), 'characters')
    #print(data.decode())
    root = ET.fromstring(data)

    results = root.findall('result')
    print("result: ", results)
    count += 1
    sum += int(item.find('count').text)

# %%
jsonfile = '''
{
  "comments":[
    {
      "name":"Qirui",
      "count":97
    },
    {
      "name":"Boab",
      "count":96
    },
    {
      "name":"Brunon",
      "count":93
    },
    {
      "name":"Elita",
      "count":92
    },
    {
      "name":"Jay",
      "count":89
    },
    {
      "name":"Gael",
      "count":88
    },
    {
      "name":"Cathal",
      "count":83
    },
    {
      "name":"Iseabel",
      "count":81
    },
    {
      "name":"Dilsa",
      "count":79
    },
    {
      "name":"Kizhi",
      "count":76
    },
    {
      "name":"Valo",
      "count":71
    },
    {
      "name":"John",
      "count":71
    },
    {
      "name":"Tayo",
      "count":69
    },
    {
      "name":"Dacia",
      "count":66
    },
    {
      "name":"Sarka",
      "count":65
    },
    {
      "name":"Hamish",
      "count":65
    },
    {
      "name":"Jessica",
      "count":59
    },
    {
      "name":"Sebastien",
      "count":56
    },
    {
      "name":"Lachlainn",
      "count":56
    },
    {
      "name":"Kiaran",
      "count":55
    },
    {
      "name":"Kit",
      "count":55
    },
    {
      "name":"Cerys",
      "count":55
    },
    {
      "name":"Kelisse",
      "count":52
    },
    {
      "name":"Yann",
      "count":49
    },
    {
      "name":"Meyzhward",
      "count":48
    },
    {
      "name":"Rayhan",
      "count":48
    },
    {
      "name":"Sadie",
      "count":48
    },
    {
      "name":"Payton",
      "count":48
    },
    {
      "name":"Youer",
      "count":41
    },
    {
      "name":"Mathew",
      "count":39
    },
    {
      "name":"Carwyn",
      "count":37
    },
    {
      "name":"Jocelyn",
      "count":35
    },
    {
      "name":"Christy",
      "count":34
    },
    {
      "name":"Bob",
      "count":31
    },
    {
      "name":"Guerin",
      "count":26
    },
    {
      "name":"Sophi",
      "count":23
    },
    {
      "name":"Madox",
      "count":20
    },
    {
      "name":"Roni",
      "count":17
    },
    {
      "name":"Savanna",
      "count":16
    },
    {
      "name":"Demileigh",
      "count":15
    },
    {
      "name":"Rylee",
      "count":13
    },
    {
      "name":"Roslyn",
      "count":13
    },
    {
      "name":"Faiza",
      "count":10
    },
    {
      "name":"Keira",
      "count":9
    },
    {
      "name":"Madeline",
      "count":6
    },
    {
      "name":"Talha",
      "count":5
    },
    {
      "name":"Ailidh",
      "count":5
    },
    {
      "name":"Oluwatimilehin",
      "count":3
    },
    {
      "name":"Amahle",
      "count":2
    },
    {
      "name":"Cieran",
      "count":1
    }
  ]
}
'''

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl
import re
import json

api_key = False
# If you have a Google Places API key, enter it here
api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/xml?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/xml?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

count, sum = 0, 0
while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms) 
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    print(uh)

    data = uh.read().decode()
    print("data: ", data)
    data = re.sub(u"[\x00-\x08\x0b-\x0c\x0e-\x1f]+", u"", data)
    print('Retrieved', len(data), 'characters')
    #print(data.decode())
    info = json.loads(jsonfile)


counts = list()
# Extract the list of counts from the JSON data
counts = [comment['count'] for comment in info['comments']]

total = 0
for num in counts:
    total += num

# Print the result
print('The sum of the counts is:', total)
# Out:
# The sum of the counts is: 2311

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai.api_key = "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"

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

# %%
prompt = f"""
Plz write a python program, compute the sum of the numbers in the jsonfile: \ 
```{jsonfile}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Here's the Python program to compute the sum of the numbers in the given JSON file:
#
# ```python
# import json
#
# # Load the JSON file
# with open('file.json') as f:
#     data = json.load(f)
#
# # Extract the list of counts from the JSON data
# counts = [comment['count'] for comment in data['comments']]
#
# # Compute the sum of the counts
# total = sum(counts)
#
# # Print the result
# print('The sum of the counts is:', total)
# ```
#
# Note: Replace `file.json` with the actual name of the JSON file you want to load.
